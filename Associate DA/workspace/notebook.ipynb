# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Data Validation
# Describe the validation tasks you performed and what you found. Have you made any changes to the data to enable further analysis? Remember to describe what you did for every column in the data.
#
# In processing this csv file, I did the following processes with Microsoft Excel:
#
# 1. I created a copy of claims.csv and renamed the original file as claims_original and renamed the new one as claims_processed. In other processes listed here, I only change the claims_processed file.
# 2. For every column in the csv file, I checked the data according to data dictionary:
#
# 	i) Using remove duplicates on Claim ID column and no duplicate was found. So this column is valid.
#
#     ii) Cheking all entries in Time to Close, Amount Paid and Individuals on Claim column. In row 60, the entry of Time to Close is -57, which should be corrected to 57. Other than that, there are no negative entries and they are all numeric. So these columns are valid.
#
#     iii) Using replace function to remove the first two characters in Claim Amount cloumn and keep the result numeric. So this column is valid.
#
#     iv) Using filter to see which different entries are in Location and Linked Cases columns. The entries are as described in the data dictionary. So these columns are valid.
#
#     v) There are missing values in Cause column. I replace them with "unknown" and check this column with filters. There are only three different entries. So this column is valid.
#
# With this, the data cleaning step is over and the data is now ready-to-use.

# %%
# Preparation for the data viz
import pandas as pd

viz_1 = pd.read_csv('data_viz_1.csv')
viz_2 = pd.read_csv('claims_processed.csv')
viz_3 = pd.read_csv('data_viz_3.csv')

# %% [markdown]
# ## Data Discovery and Visualization
# Describe what you found in the analysis and how the visualizations answer the customer questions in the project brief. In your description you should:
# - Include at least two different data visualizations to demonstrate the characteristics of single variables
# - Include at least one data visualization to demonstrate the relationship between two or more variables
# - Describe how your analysis has answered the business questions in the project brief
#
# There are three questions to answer for our customers, we answer them here one by one with plots:
# 1. How does the number of claims differ across locations?
#
# We create two column charts to show this. First, I show the relationship between the number of cases and location. In Figure 1: Relationship between claim cases and location, it can be seen that there are the most cases in SAO LUIS and the least in NATAL.

# %%
# This is a chart, switch to the DataCamp editor to view and configure it.
# Out:
#     location  count of claims  count of individuals
# 0     RECIFE               25                   106
# 1   SAO LUIS               30                   138
# 2  FORTALEZA               22                    69
# 3      NATAL               21                   168

# %% [markdown]
# However, one case may concern multiple people. Therefore, it is better to check the total number of individuals in different location. We can see that in Figure 2: Relationship between claim individuals and location, NATAL has the most claiming people. Note that in the last figure, it can be seen that NATAL has the least cases! Therefore, it can be concluded that generally, the cases claimed in NATAL is more severe than other locations. This should be paid enough attention!

# %%
# This is a chart, switch to the DataCamp editor to view and configure it.
# Out:
#     location  count of claims  count of individuals
# 0     RECIFE               25                   106
# 1   SAO LUIS               30                   138
# 2  FORTALEZA               22                    69
# 3      NATAL               21                   168

# %% [markdown]
# 2. What is the distribution of time to close claims?
# In Figure 3: Number of days it took for the claim to be closed, I create a histogram to show the distribution of time to close claims. As seen in the chart, most cases could be closed within about 1200 days. Apart from that, a small partition of the cases were closed within about 2400 days. Very few cases lasted about 3000 days.

# %%
import matplotlib.pyplot as plt

viz_2['Time to Close'].hist(bins = 15)
plt.xlabel('Time to Close')
plt.ylabel('count')
plt.title('Figure 3: Number of days it took for the claim to be closed')
plt.show()

# %% [markdown]
# 3. How does the average time to close claims differ by location?
#
# In Figure 4: Average time to close claims in different locations, we see that cases in SAO LUIS took the most time to solve (over 1000 days), while those in NATAL took the least time (less than 600 days).

# %%
# This is a chart, switch to the DataCamp editor to view and configure it.
# Out:
#     location  average_close_time
# 0     RECIFE          860.680000
# 1   SAO LUIS         1030.066667
# 2  FORTALEZA          775.500000
# 3      NATAL          581.142857

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric, have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
