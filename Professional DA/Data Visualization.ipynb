# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('travel_insurance.csv')

# %%
df
# Out:
#       Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0      31             Government Sector           Yes        400000
# 1      31  Private Sector/Self Employed           Yes       1250000
# 2      34  Private Sector/Self Employed           Yes        500000
# 3      28  Private Sector/Self Employed           Yes        700000
# 4      28  Private Sector/Self Employed           Yes        700000
# ...   ...                           ...           ...           ...
# 1982   33  Private Sector/Self Employed           Yes       1500000
# 1983   28  Private Sector/Self Employed           Yes       1750000
# 1984   28  Private Sector/Self Employed           Yes       1150000
# 1985   34  Private Sector/Self Employed           Yes       1000000
# 1986   34  Private Sector/Self Employed           Yes        500000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 0                 6                1            No                  No
# ...

# %% [markdown]
# Here, we split the dataset to two parts: customers and non-customers.

# %%
df_customers = df[df['TravelInsurance']==1]
df_non_customers = df[df['TravelInsurance']==0]

# %% [markdown]
# 1. Age

# %%
ax = sns.countplot(x='Age', data=df_customers)
ax.set_yticks([0,50,100,150,200,250,300,350,400])
plt.title('Distribution of age of customers')
# Out:
# Text(0.5, 1.0, 'Distribution of age of customers')

# %%
ax = sns.countplot(x='Age', data=df_non_customers)
ax.set_yticks([0,50,100,150,200,250,300,350,400])
plt.title('Distribution of age of non-customers')
# Out:
# Text(0.5, 1.0, 'Distribution of age of non-customers')

# %% [markdown]
# Age of 28 is quite particular, but we cannot say anything about the difference.

# %% [markdown]
# 2. Employment type

# %%
sorted_counts = df_customers['Employment Type'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Distribution of employment type of customers')
# Out:
# Text(0.5, 1.0, 'Distribution of employment type of customers')

# %%
sorted_counts = df_non_customers['Employment Type'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Distribution of employment type of non-customers')
# Out:
# Text(0.5, 1.0, 'Distribution of employment type of non-customers')

# %% [markdown]
# Self-employed people tend to buy insurence

# %% [markdown]
# 3. Graduation

# %%
sorted_counts = df_customers['GraduateOrNot'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Have customers graduated?')
# Out:
# Text(0.5, 1.0, 'Have customers graduated?')

# %%
sorted_counts = df_non_customers['GraduateOrNot'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Have non-customers graduated?')
# Out:
# Text(0.5, 1.0, 'Have non-customers graduated?')

# %% [markdown]
# Nearly no difference

# %% [markdown]
# 4. Annual income

# %%
df_customers['AnnualIncome'].hist()
plt.title('Annual income of customers')
plt.xlabel('Annual income ($)')
plt.ylabel('count')
print('Average:', df_customers['AnnualIncome'].mean())
print('Median:', df_customers['AnnualIncome'].median())
# Out:
# Average: 1133239.4366197183
# Median: 1250000.0

# %%
df_non_customers['AnnualIncome'].hist()
plt.xlabel('Annual income ($)')
plt.ylabel('count')
plt.title('Annual income of non-customers')
print('Average:', df_non_customers['AnnualIncome'].mean())
print('Median:', df_non_customers['AnnualIncome'].median())
# Out:
# Average: 821299.9216914644
# Median: 800000.0

# %% [markdown]
# There is an obvious gap between customers and non-customers in annual income. (Use this!)

# %%
df_customers['AnnualIncome'].hist(alpha = 0.7, figsize=(10, 6))
df_non_customers['AnnualIncome'].hist(alpha = 0.7)
plt.legend(['Customers','Non-customers'], loc = 2)
plt.xlabel('Annual income ($)')
plt.ylabel('count')
plt.title('Annual income of customers and non-customers')
#plt.figure(figsize=(120, 60))
plt.show()

# %% [markdown]
# 5. Number of family members

# %%
ax = sns.countplot(x='FamilyMembers', data=df_customers)
ax.set_yticks([0,50,100,150,200,250,300,350])
plt.title('Distribution of number of family members of customers')
# Out:
# Text(0.5, 1.0, 'Distribution of number of family members of customers')

# %%
ax = sns.countplot(x='FamilyMembers', data=df_non_customers)
ax.set_yticks([0,50,100,150,200,250,300,350])
plt.title('Distribution of number of family members of non-customers')
# Out:
# Text(0.5, 1.0, 'Distribution of number of family members of non-customers')

# %% [markdown]
# No difference

# %% [markdown]
# 6. Chronic diseases

# %%
labels = ['No', 'Yes']
sorted_counts = df_customers['ChronicDiseases'].value_counts()
plt.pie(sorted_counts, startangle = 90, counterclock = False, autopct='%1.1f%%', labels = labels)
plt.title('Do customers have chronic diseases?')
# Out:
# Text(0.5, 1.0, 'Do customers have chronic diseases?')

# %%
labels = ['No', 'Yes']
sorted_counts = df_non_customers['ChronicDiseases'].value_counts()
plt.pie(sorted_counts, startangle = 90, counterclock = False, autopct='%1.1f%%', labels = labels)
plt.title('Do non-customers have chronic diseases?')
# Out:
# Text(0.5, 1.0, 'Do non-customers have chronic diseases?')

# %% [markdown]
# No difference

# %% [markdown]
# 7. Frequent flyer

# %%
sorted_counts = df_customers['FrequentFlyer'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Are customers frequent flyer?')
# Out:
# Text(0.5, 1.0, 'Are customers frequent flyer?')

# %%
sorted_counts = df_non_customers['FrequentFlyer'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Are non-customers frequent flyer?')
# Out:
# Text(0.5, 1.0, 'Are non-customers frequent flyer?')

# %% [markdown]
# Frequent flyers are more likely to buy insurence.

# %% [markdown]
# For the visualization need, we change it to bar chart.

# %%
sorted_counts = df_customers['FrequentFlyer'].value_counts()
plt.bar(sorted_counts.index, sorted_counts.values, color = ['red','green'], alpha = 0.6)
plt.yticks([200,400,600,800,1000,1200])
plt.title('Are customers frequent flyer?')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sorted_counts = df_non_customers['FrequentFlyer'].value_counts()
plt.bar(sorted_counts.index, sorted_counts.values, color = ['red','green'], alpha = 0.6)
plt.yticks([200,400,600,800,1000,1200])
plt.title('Are non-customers frequent flyer?')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sorted_counts.values
# Out:
# array([471, 239], dtype=int64)

# %% [markdown]
# 8. Ever travelled abroad

# %%
sorted_counts = df_customers['EverTravelledAbroad'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Have customers ever travelled abroad?')
# Out:
# Text(0.5, 1.0, 'Have customers ever travelled abroad?')

# %%
sorted_counts = df_non_customers['EverTravelledAbroad'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%')
plt.title('Have non-customers ever travelled abroad?')
# Out:
# Text(0.5, 1.0, 'Have non-customers ever travelled abroad?')

# %% [markdown]
# People ever travelled abroad are more likely to buy insurence.

# %% [markdown]
# Visualization with two variables involved would be:
